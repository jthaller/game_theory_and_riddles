# %%
130.8933 + 260*(-0.2565)
slope, intercept, r_value, p_value, std_err = stats.linregress(men.avg_drive, men.acc_fairway)
print(f"{slope}\n{intercept}\n{r_value}\n{p_value}\n{std_err}")
mod = sfm.ols('acc_fairway ~ avg_drive', data = men) # regress I onto T
res = mod.fit()
print(res.params)

women.avg_drive[:5]
# Out:
# -0.3878871739176873
# 174.92546067591076
# -0.6075988227151213
# 2.8846142861451688e-21
# 0.036309910667030265
# Intercept    174.925461
# avg_drive     -0.387887
# dtype: float64
# 0    243.2
# 1    254.5
# 2    253.1
# 3    228.1
# 4    240.8
# Name: avg_drive, dtype: float64

# %%
# prediction
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)

print(f"{slope}\n{intercept}")
def predict_man(x):
       return slope*x + intercept
print(f"y={predict_man(260)}")
# Out:
# -0.25649070111477706
# 130.8933145774214
# y=64.20573228757935

# %%
# prediction. Q4
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)

print(f"{slope}\n{intercept}")
def predict_man(x):
       return slope*x + intercept
print(f"y={predict_woman(260)}")
# Out:
# -0.25649070111477706
# 130.8933145774214
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/linear_reg_interactive.py in <module>
#       5 def predict_man(x):
#       6        return slope*x + intercept
# ----> 7 print(f"y={predict_woman(260)}")
#
# NameError: name 'predict_woman' is not defined

# %%
# prediction. Q4
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)

print(f"{slope}\n{intercept}")
def predict_woman(x):
       return slope*x + intercept
print(f"y={predict_woman(260)}")
# Out:
# -0.25649070111477706
# 130.8933145774214
# y=64.20573228757935

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)
def predict(x):
       return slope*x + intercept
print(f"y={predict(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n)
print(t)
print(f"lower 95%: {predict(260) - std_err*upper_q}")
print(f"upper 95%: {predict(260) + std_err*upper_q}")
# Out:
# y=64.20573228757935
# 1.6546170347128435
# lower 95%: 64.11832758251605
# upper 95%: 64.29313699264266

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.025, n)
print(t)
print(f"lower 95%: {predict(260) - std_err*upper_q}")
print(f"upper 95%: {predict(260) + std_err*upper_q}")
# Out:
# y=64.20573228757935
# 1.975189163068866
# lower 95%: 64.11832758251605
# upper 95%: 64.29313699264266

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.025, n)
print(t)
print(f"lower 95%: {predict(260) - t}")
print(f"upper 95%: {predict(260) + std_err*upper_q}")
# Out:
# y=64.20573228757935
# 1.975189163068866
# lower 95%: 62.23054312451048
# upper 95%: 64.29313699264266

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.025, n)
print(t)
print(f"lower 95%: {predict(260) - t}")
print(f"upper 95%: {predict(260) + t}")
# Out:
# y=64.20573228757935
# 1.975189163068866
# lower 95%: 62.23054312451048
# upper 95%: 66.18092145064821

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.025, n-1)
print(t)
print(f"lower 95%: {predict(260) - t}")
print(f"upper 95%: {predict(260) + t}")
# Out:
# y=64.20573228757935
# 1.9752875076954723
# lower 95%: 62.23044477988388
# upper 95%: 66.18101979527482

# %%
130.8933 + 260*(-0.2565)
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
alpha = 0.05                                                                                    
upper_q = t.ppf(1 - alpha / 2, n - p - 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/linear_reg_interactive.py in <module>
#       3 p = 2 # variables
#       4 alpha = 0.05
# ----> 5 upper_q = t.ppf(1 - alpha / 2, n - p - 1)
#
# AttributeError: 'numpy.float64' object has no attribute 'ppf'

# %%
from scipy.stats import t 
130.8933 + 260*(-0.2565)
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
alpha = 0.05                                                                                    
upper_q = t.ppf(1 - alpha / 2, n - p - 1)

# %%
from scipy.stats import t 
130.8933 + 260*(-0.2565)
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
alpha = 0.05                                                                                    
upper_q = t.ppf(1 - alpha / 2, n - p - 1)
print(upper_q)
# Out:
# 1.9754880582258318

# %%
from scipy.stats import t 
130.8933 + 260*(-0.2565)
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
alpha = 0.025                                                                                    
upper_q = t.ppf(1 - alpha / 2, n - p - 1)
print(upper_q)
# Out:
# 2.2635293069018716

# %%
from scipy.stats import t 
130.8933 + 260*(-0.2565)
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
alpha = 0.05                                                                                    
upper_q = t.ppf(1 - alpha / 2, n - p - 1)
print(upper_q)
# Out:
# 1.9754880582258318

# %%
from scipy.stats import t 
130.8933 + 260*(-0.2565)
n = women.acc_fairway.size # counts                                                                                        
p = 2 # variables                                                                                           
alpha = 0.05                                                                                    
upper_q = t.ppf(1 - alpha / 2, n - p - 1)
print(upper_q)
# Out:
# 1.9754880582258318

# %%
## QUIZ
import pandas as pd
URL = 'http://users.stat.ufl.edu/~winner/data/pgalpga2008.dat'
df = pd.read_table(URL, delimiter='    ', names = ['avg_drive', 'acc_fairway', 'sex'])
men = df[df['sex'] == 2]
women = df[df['sex'] == 1]
men.head()
# Out:
#      avg_drive  acc_fairway  sex
# 157      290.3         59.5    2
# 158      302.1         54.7    2
# 159      287.1         62.4    2
# 160      282.7         65.4    2
# 161      299.1         52.8    2

# %%
# Q1: plotting
import seaborn as sns
sns.set_theme(style='darkgrid')
sns.scatterplot(x = men.avg_drive, y=men.acc_fairway, label = 'Men')
plt.title('Men vs. Women')
plt.xlabel('Avg Drive Dist')
plt.ylabel('Fairway Accuracy')
# plt.legend(['Men', 'Women'])
sns.scatterplot(x = women.avg_drive, y=women.acc_fairway, label = 'Women')
plt.plot()
# Out:
# []

# %%
# Q2: linear regression stats
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)
print(f"slope: {slope}\nintercept: {intercept}\nstd: {std_err}")

import statsmodels.formula.api as sfm
mod = sfm.ols('acc_fairway ~ avg_drive', data = women) # regress I onto T
res=mod.fit()
print(res.summary())
# Out:
# slope: -0.25649070111477706
# intercept: 130.8933145774214
# std: 0.044244613223226675
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            acc_fairway   R-squared:                       0.178
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     33.61
# Date:                Sun, 29 Nov 2020   Prob (F-statistic):           3.66e-08
# Time:                        19:29:17   Log-Likelihood:                -482.00
# No. Observations:                 157   AIC:                             968.0
# Df Residuals:                     155   BIC:                             974.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    130.8933     10.928     11.978      0.000     109.307     152.480
# avg_drive     -0.2565      0.044     -5.797      0.000      -0.344      -0.169
# ==============================================================================
# Omnibus:                       38.145   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.558
# Skew:                          -1.122   Prob(JB):                     1.75e-16
# Kurtosis:                       5.462   Cond. No.                     6.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Plot with fitted lines
slope, intercept, r_value, p_value, std_err = stats.linregress(men.avg_drive, men.acc_fairway)
sns.scatterplot(x = men.avg_drive, y=men.acc_fairway, label = 'Men')
plt.plot(men.avg_drive, intercept + slope*men.avg_drive, 'r')
plt.title('Men vs. Women')
plt.xlabel('Avg Drive Dist'), plt.ylabel('Fairway Accuracy')
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)
sns.scatterplot(x = women.avg_drive, y=women.acc_fairway, label = 'Women')
sns.scatterplot(x=[260], y=[74.075], label='prediction', markers='x')
plt.plot(women.avg_drive, intercept + slope*women.avg_drive, 'b', label='fitted line women')
plt.plot()
# Out:
# []

# %%
# prediction. Q4
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)

print(f"{slope}\n{intercept}")
def predict_woman(x):
       return slope*x + intercept
print(f"y={predict_woman(260)}")
# Out:
# -0.25649070111477706
# 130.8933145774214
# y=64.20573228757935

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n-1)
print(t)
print(f"lower 95%: {predict(260) - t}")
print(f"upper 95%: {predict(260) + t}")
# Out:
# y=64.20573228757935
# 1.6546799956696048
# lower 95%: 62.55105229190975
# upper 95%: 65.86041228324896

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n-2)
print(t)
print(f"lower 95%: {predict(260) - t}")
print(f"upper 95%: {predict(260) + t}")
# Out:
# y=64.20573228757935
# 1.6547437739175987
# lower 95%: 62.55098851366175
# upper 95%: 65.86047606149695

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n-2)
print(t)
xmean = np.mean(women.avg_drive)
sx = np.var(women.avg_drive) # sample variance of driving range
k = sqrt(1 + 1/n + (60-x_mean)**2/((n-1)sx**2))
print(f"lower 95%: {predict(260) - t*std_error*k}")
print(f"upper 95%: {predict(260) + t}")
# Out:
#   File "<ipython-input-143-b0dc04c96f3f>", line 18
#     k = sqrt(1 + 1/n + (60-x_mean)**2/((n-1)sx**2))
#                                              ^
# SyntaxError: invalid syntax

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n-2)
print(t)
xmean = np.mean(women.avg_drive)
sx = np.var(women.avg_drive) # sample variance of driving range
k = sqrt(1 + 1/n + (60-x_mean)**2/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_error*k}")
print(f"upper 95%: {predict(260) + t}")
# Out:
# y=64.20573228757935
# 1.6547437739175987
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/linear_reg_interactive.py in <module>
#      16 xmean = np.mean(women.avg_drive)
#      17 sx = np.var(women.avg_drive) # sample variance of driving range
# ---> 18 k = sqrt(1 + 1/n + (60-x_mean)**2/((n-1)*sx**2))
#      19 print(f"lower 95%: {predict(260) - t*std_error*k}")
#      20 print(f"upper 95%: {predict(260) + t}")
#
# NameError: name 'x_mean' is not defined

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n-2)
print(t)
xmean = np.mean(women.avg_drive)
sx = np.var(women.avg_drive) # sample variance of driving range
k = sqrt(1 + 1/n + (60-xmean)**2/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_error*k}")
print(f"upper 95%: {predict(260) + t}")
# Out:
# y=64.20573228757935
# 1.6547437739175987
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/linear_reg_interactive.py in <module>
#      17 sx = np.var(women.avg_drive) # sample variance of driving range
#      18 k = sqrt(1 + 1/n + (60-xmean)**2/((n-1)*sx**2))
# ---> 19 print(f"lower 95%: {predict(260) - t*std_error*k}")
#      20 print(f"upper 95%: {predict(260) + t}")
#
# NameError: name 'std_error' is not defined

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n-2)
print(t)
xmean = np.mean(women.avg_drive)
sx = np.var(women.avg_drive) # sample variance of driving range
k = sqrt(1 + 1/n + (60-xmean)**2/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_err*k}")
print(f"upper 95%: {predict(260) + t}")
# Out:
# y=64.20573228757935
# 1.6547437739175987
# lower 95%: 64.1312752776612
# upper 95%: 65.86047606149695

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n-2)
print(t)
xmean = np.mean(women.avg_drive)
sx = np.var(women.avg_drive) # sample variance of driving range
k = sqrt(1 + 1/n + (60-xmean)**2/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_err*k}")
print(f"upper 95%: {predict(260) + t*std_err*k}")
# Out:
# y=64.20573228757935
# 1.6547437739175987
# lower 95%: 64.1312752776612
# upper 95%: 64.2801892974975

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n-2)
print(f"t={t}"")
xmean = np.mean(women.avg_drive)
sx = np.var(women.avg_drive) # sample variance of driving range
k = sqrt(1 + 1/n + (60-xmean)**2/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_err*k}")
print(f"upper 95%: {predict(260) + t*std_err*k}")
# Out:
#   File "<ipython-input-148-eb3d16f91482>", line 15
#     print(f"t={t}"")
#                     ^
# SyntaxError: EOL while scanning string literal

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n-2)
print(f"t={t}")
xmean = np.mean(women.avg_drive)
sx = np.var(women.avg_drive) # sample variance of driving range
k = sqrt(1 + 1/n + (60-xmean)**2/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_err*k}")
print(f"upper 95%: {predict(260) + t*std_err*k}")
# Out:
# y=64.20573228757935
# t=1.6547437739175987
# lower 95%: 64.1312752776612
# upper 95%: 64.2801892974975

# %%
# prediction. Q4
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)

print(f"{slope}\n{intercept}")
def predict_woman(x):
       return slope*x + intercept
print(f"y={predict_woman(260)}")1
# Out:
#   File "<ipython-input-150-fb589744aade>", line 7
#     print(f"y={predict_woman(260)}")1
#                                     ^
# SyntaxError: invalid syntax

# %%
# prediction. Q4
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)

print(f"{slope}\n{intercept}")
def predict_woman(x):
       return slope*x + intercept
print(f"y={predict_woman(260)}")
# Out:
# -0.25649070111477706
# 130.8933145774214
# y=64.20573228757935

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n-2)
print(f"t={t}")
xmean = np.mean(women.avg_drive)
sx = np.var(women.avg_drive) # sample variance of driving range
k = sqrt(1 + 1/n + (60-xmean)**2/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_err*k}")
print(f"upper 95%: {predict(260) + t*std_err*k}")
# Out:
# y=64.20573228757935
# t=1.6547437739175987
# lower 95%: 64.1312752776612
# upper 95%: 64.2801892974975

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.05, n-2)
print(f"t={t}")
xmean = np.mean(women.avg_drive)
print(xmean)
sx = np.var(women.avg_drive) # sample variance of driving range
print(sx)
k = sqrt(1 + 1/n + (60-xmean)**2/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_err*k}")
print(f"upper 95%: {predict(260) + t*std_err*k}")
# Out:
# y=64.20573228757935
# t=1.6547437739175987
# 246.80127388535033
# 89.55808754919062
# lower 95%: 64.1312752776612
# upper 95%: 64.2801892974975

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.025, n-2)
print(f"t={t}")
xmean = np.mean(women.avg_drive)
print(xmean)
sx = np.var(women.avg_drive) # sample variance of driving range
print(sx)
k = sqrt(1 + 1/n + (60-xmean)**2/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_err*k}")
print(f"upper 95%: {predict(260) + t*std_err*k}")
# Out:
# y=64.20573228757935
# t=1.9753871310468782
# 246.80127388535033
# 89.55808754919062
# lower 95%: 64.11684757834105
# upper 95%: 64.29461699681765

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.025, n-2)
print(f"t={t}")
xmean = np.mean(women.avg_drive)
print(xmean)
sx = np.var(women.avg_drive) # sample variance of driving range
print(sx)
k = sqrt(1 + 1/n + ((260-xmean)**2)/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_err*k}")
print(f"upper 95%: {predict(260) + t*std_err*k}")
# Out:
# y=64.20573228757935
# t=1.9753871310468782
# 246.80127388535033
# 89.55808754919062
# lower 95%: 64.11804808027512
# upper 95%: 64.29341649488359

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.025, n-2)
print(f"t={t}")
xmean = np.mean(women.avg_drive)
print(xmean)
sx = np.var(women.avg_drive, ddof=1) # sample variance of driving range
print(sx)
k = sqrt(1 + 1/n + ((260-xmean)**2)/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_err*k}")
print(f"upper 95%: {predict(260) + t*std_err*k}")
# Out:
# y=64.20573228757935
# t=1.9753871310468782
# 246.80127388535033
# 90.13217785399311
# lower 95%: 64.11804815728544
# upper 95%: 64.29341641787326

# %%
# prediction. Q4
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)

print(f"{slope}\n{intercept}")
def predict_woman(x):
       return slope*x + intercept
print(f"y={predict_woman(260)}")
# Out:
# -0.25649070111477706
# 130.8933145774214
# y=64.20573228757935

# %%
# Q2: linear regression stats
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)
print(f"slope: {slope}\nintercept: {intercept}\nstd: {std_err}")

import statsmodels.formula.api as sfm
mod = sfm.ols('acc_fairway ~ avg_drive', data = women) # regress I onto T
res=mod.fit()
print(res.summary())
# Out:
# slope: -0.25649070111477706
# intercept: 130.8933145774214
# std: 0.044244613223226675
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            acc_fairway   R-squared:                       0.178
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     33.61
# Date:                Sun, 29 Nov 2020   Prob (F-statistic):           3.66e-08
# Time:                        20:22:53   Log-Likelihood:                -482.00
# No. Observations:                 157   AIC:                             968.0
# Df Residuals:                     155   BIC:                             974.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    130.8933     10.928     11.978      0.000     109.307     152.480
# avg_drive     -0.2565      0.044     -5.797      0.000      -0.344      -0.169
# ==============================================================================
# Omnibus:                       38.145   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.558
# Skew:                          -1.122   Prob(JB):                     1.75e-16
# Kurtosis:                       5.462   Cond. No.                     6.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# prediction. Q4
slope, intercept, r_value, p_value, std_err = stats.linregress(women.avg_drive, women.acc_fairway)

print(f"{slope}\n{intercept}")
def predict_woman(x):
       return slope*x + intercept
print(f"y={predict_woman(260)}")
# Out:
# -0.25649070111477706
# 130.8933145774214
# y=64.20573228757935

# %%
# gives a 95% posterior predictive interval for 
# the driving accuracy of a new female golfer whose 
# average driving distance is x=260x=260 yards

print(f"y={predict_woman(260)}")
from scipy.stats import t                                                                            
n = women.avg_drive.size # counts                                                                                        
p = 2 # variables                                                                                           
# alpha = 0.05
# upper_q = t.ppf(1 - alpha / 2, n - p - 1)
from scipy import stats
#Studnt, n=999, p<0.05, 2-tail
#equivalent to Excel TINV(0.05,999)
t=stats.t.ppf(1-0.025, n-2)
print(f"t={t}")
xmean = np.mean(women.avg_drive)
sx = np.var(women.avg_drive, ddof=1) # sample variance of driving range
k = sqrt(1 + 1/n + ((260-xmean)**2)/((n-1)*sx**2))
print(f"lower 95%: {predict(260) - t*std_err*k}")
print(f"upper 95%: {predict(260) + t*std_err*k}")
# Out:
# y=64.20573228757935
# t=1.9753871310468782
# lower 95%: 64.11804815728544
# upper 95%: 64.29341641787326
